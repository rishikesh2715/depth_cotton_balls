# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n-seg.pt")

# %%
result = model.train(data="tennis_ball\\data.yaml", epochs=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.4.9 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203  Python-3.13.5 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# ...
